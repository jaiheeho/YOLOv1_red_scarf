# %%
# %matplotlib notebook

import os
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
files = os.listdir("result")

# %%
fig, axes = plt.subplots(nrows = 5, ncols= 4, figsize=(7, 7),  gridspec_kw = {'wspace':0, 'hspace':0})
good_files = [ f for f in files if f[0] == 'g']
print(good_files)

for i in range(4):
    for j in range(5):
        ax = axes[j][i]
        path_to_file = os.path.join('result',good_files[i*5+j])
        img = Image.open(path_to_file)
        ax.imshow(img)
        ax.axis('off')
        ax.set_aspect('equal')

fig.subplots_adjust(wspace=0, hspace=0)
plt.tight_layout()

fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="699.444462973395">
# ['good_9.png', 'good_7.png', 'good_0.png', 'good_19.png', 'good_10.png', 'good_17.png', 'good_1.png', 'good_6.png', 'good_8.png', 'good_16.png', 'good_11.png', 'good_18.png', 'good_12.png', 'good_15.png', 'good_20.png', 'good_5.png', 'good_2.png', 'good_14.png', 'good_13.png', 'good_3.png', 'good_4.png']

# %%
fig, axes = plt.subplots(nrows = 1, ncols= 3, figsize=(7, 7))
bad_files = [ f for f in files if f[0] == 'b']
print (bad_files)
for i in range(3):
    ax = axes[i]
    path_to_file = os.path.join('result',bad_files[i])
    img = Image.open(path_to_file)
    img_np = np.array(img)/255.0
    ax.axis('off')
    ax.set_aspect('equal')

fig.subplots_adjust(wspace=0, hspace=0)fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="699.444462973395">
# ['bad_0.png', 'bad_3.png', 'bad_2.png']
